# %%
# 완성 코드
import pandas as pd
file_path = r'C:\Users\user\dev\소스파일\FE\gongmo2\src\kmap\datalist.xlsx'
df = pd.read_excel(file_path)
df = df[['법정동코드', '법정동명']]
data_dict = {item : 0 for item in df['법정동명']}
#data_dict = dict(zip(df['법정동명'], [0] * len(df)))

import requests
url = 'http://apis.data.go.kr/B552474/SenuriService/getJobList'
servicekey = 'nSsjmwW7P8v4/4snOCYe0og5/8LwRd7sZhBLYsnK559jxSdyQ1JpibKEmxMxEkSYvvju+HGCTch4vsNZVQY1Ng=='
params ={'serviceKey' : servicekey, 'pageNo' : '1', 'numOfRows' : '10000' }
response = requests.get(url, params=params)


import xml.etree.ElementTree as ET
response_content = response.content
root = ET.fromstring(response_content)
#root_items = root.findall('.//item')
#items = [ {'workPlcNm' : item } for item in root_items]

items = []
cnt = 0
for item in root.findall('.//item'):
    # 추후 필요 없는 속성 제거
    try:        
        job = {
            # 'acptMthd': item.find('acptMthd').text,
            # 'deadline': item.find('deadline').text,
            # 'emplymShp': item.find('emplymShp').text,
            # 'emplymShpNm': item.find('emplymShpNm').text,
            # 'frDd': item.find('frDd').text,
            'jobId': item.find('jobId').text,
            'oranNm': item.find('oranNm').text,
            # 'organYn': item.find('organYn').text,
            'recrtTitle': item.find('recrtTitle').text,
            # 'stmId': item.find('stmId').text,
            # 'stmNm': item.find('stmNm').text,
            'toDd': item.find('toDd').text,
            # 'workPlc': item.find('workPlc').text,
            'workPlcNm': item.find('workPlcNm').text,
            'interest' : '⬜'
        }
        items.append(job)
        cnt += 1
    except :
        pass 


print(items)
print(cnt)

import json

with open("table_data.json", "w", encoding='utf-8') as f:
    json.dump(items, f, ensure_ascii=False, indent=4)
# Out:
# [{'jobId': 'KJKO002406140007', 'oranNm': '주식회사 인성종합관리', 'recrtTitle': '시흥장현포레미엘더파크 외곽 미화원 구인 (복지카드 우대)', 'toDd': '20240713', 'workPlcNm': '경기 시흥시', 'interest': '⬜'}, {'jobId': 'K161132406140023', 'oranNm': '일진제강(주)', 'recrtTitle': '일진제강(주) 임실사업장 환경미화직 채용', 'toDd': '20240813', 'workPlcNm': '전북 임실군', 'interest': '⬜'}, {'jobId': 'KJKM002406140004', 'oranNm': '오픈핸즈주식회사', 'recrtTitle': '[오픈핸즈] 환경미화 직무 채용', 'toDd': '20240620', 'workPlcNm': '경기 성남시 분당구', 'interest': '⬜'}, {'jobId': 'KJDH002406140005', 'oranNm': '（주）비엠에스종합개발', 'recrtTitle': '아파트 내부 미화원 채용', 'toDd': '20240628', 'workPlcNm': '인천 서구', 'interest': '⬜'}, {'jobId': 'KJKM002406140005', 'oranNm': '주식회사에코그린티엠', 'recrtTitle': '고등동 호반써밋판교밸리 외곽미화원 채용', 'toDd': '20240628', 'workPlcNm': '경기 성남시 수정구', 'interest': '⬜'}, {'jobId': 'KJKM002406140007', 'oranNm': '(주）이엠피서비스', 'recrtTitle': '성남시 분당구 산운마을11단지아파트 실내 미화원 모집 공고', 'toDd': '20240810', 'workPlcNm': '경기 성남시 분당구', 'interest': '⬜'}, {'jobId': 'K170082406140020', 'oranNm': '세종시 장애인 자립생활센터', 'recrtTitle': '세종시장애인자립생활센터 활동지원팀 직원(경력직) 채용 공고', 'toDd': '20240621', 'workPlcNm': '세종', 'interest': '⬜'}, {'jobId': 'K141212406140011', 'oranNm': '행복채움주식회사', 'recrtTitle': '행복채움 주식회사 체인지룸 업무 채용(SK실트론내)', 'toDd': '20240731', 'workPlcNm': '경북 구미시', 'interest': '⬜'}, {'jobId': 'K131522406140005', 'oranNm': '주식회사케이티서비스남부', 'recrtTitle': 'kt service남부 2024년 6월 [kt Engineer/안전보호관] 수시채용', 'toDd': '20240623', 'workPlcNm': '경남 거제시', 'interest': '⬜'}, {'jobId': 'K151122406140045', 'oranNm': '수원시체육회', 'recrtTitle': '광교복합체육센터 (관리직)근로자(기술직 9급) 채용 공고', 'toDd': '20240619', 'workPlcNm': '경기 수원시 영통구', 'interest': '⬜'}, {'jobId': 'K151122406140046', 'oranNm': '수원시체육회', 'recrtTitle': '영흥공체육시설 관리사원 채용공고(여1-여자 화장실 및 샤워실 미화)', 'toDd': '20240619', 'workPlcNm': '경기 수원시 영통구', 'interest': '⬜'}, {'jobId': 'KJKX002406140013', 'oranNm': '주식회사 인성종합관리', 'recrtTitle': '구성더포레스트 외곽 미화원 구인(복지카드우대)', 'toDd': '20240628', 'workPlcNm': '경기 용인시 기흥구', 'interest': '⬜'}, {'jobId': 'K120422406140034', 'oranNm': '엘림에스(유)', 'recrtTitle': '시흥 목감레이크 푸르지오아파트 내부 외곽미화원 채용합니다.(장애인등록증 또는 장애인복지카드 소지자 우대)', 'toDd': '20240813', 'workPlcNm': '경기 시흥시', 'interest': '⬜'}, {'jobId': 'K170082406140024', 'oranNm': '세종시 장애인 자립생활센터', 'recrtTitle': '세종시장애인자립생활센터 활동지원팀 직원(신입/시간제) 채용 공고', 'toDd': '20240621', 'workPlcNm': '세종', 'interest': '⬜'}, {'jobId': 'K152412406140020', 'oranNm': '사단법인 강원도장애인부모연대 원주시지부', 'recrtTitle': '원주시장애인부모연대 사무국 사회복지사 모집 공고', 'toDd': '20240621', 'workPlcNm': '강원 원주시', 'interest': '⬜'}, {'jobId': 'KJK1002406140001', 'oranNm': '주식회사 인성종합관리', 'recrtTitle': '이천한솔 아파트 미화원 구인(복지카드우대)', 'toDd': '20240627', 'workPlcNm': '경기 이천시', 'interest': '⬜'}, {'jobId': 'KJKE002406140001', 'oranNm': '(주)효명종합관리', 'recrtTitle': '아파트 미화원 구함-철산 래미안자이아파트', 'toDd': '20240713', 'workPlcNm': '경기 광명시', 'interest': '⬜'}, {'jobId': 'K151422406140004', 'oranNm': '주식회사백년종합관리', 'recrtTitle': '반월공단 기업체 미화원 모집', 'toDd': '20240630', 'workPlcNm': '경기 안산시 단원구', 'interest': '⬜'}, {'jobId': 'KJDH002406140004', 'oranNm': '대한종합관리(주)', 'recrtTitle': '청라 자이아파트 청소원 구인', 'toDd': '20240628', 'workPlcNm': '인천 서구', 'interest': '⬜'}, {'jobId': 'K151812406140011', 'oranNm': '(주)상우시스템', 'recrtTitle': '플로리체 위례아파트 보안대원 구인', 'toDd': '20240630', 'workPlcNm': '경기 하남시', 'interest': '⬜'}, {'jobId': 'K151422406140008', 'oranNm': '주식회사백년종합관리', 'recrtTitle': '기업체 경비원 모집', 'toDd': '20240630', 'workPlcNm': '경기 안산시 단원구', 'interest': '⬜'}, {'jobId': 'KJLJ002406140005', 'oranNm': '원주시장애인종합복지관', 'recrtTitle': '『원주시장애인종합복지관』 2024년 사회복지법인 마가렛사회복지회 원주시장애인종합복지관 직원(영양사) 채용 긴급 공고', 'toDd': '20240620', 'workPlcNm': '강원 원주시', 'interest': '⬜'}, {'jobId': 'K120312406140049', 'oranNm': '가온장애인자립생활센터', 'recrtTitle': '가온장애인자립생활센터 IL팀 직원 채용 공고', 'toDd': '20240628', 'workPlcNm': '서울 마포구', 'interest': '⬜'}, {'jobId': 'K150012406130096', 'oranNm': '사단법인꿈베이커리', 'recrtTitle': '비영리법인 사무직원 경력직 모집합니다.', 'toDd': '20240630', 'workPlcNm': '인천 중구', 'interest': '⬜'}, {'jobId': 'K163012406130012', 'oranNm': '동남기업', 'recrtTitle': '여행사무원 모집', 'toDd': '20240630', 'workPlcNm': '제주 제주시',  ...
# 288
